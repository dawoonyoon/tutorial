# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, SGDRegressor  # LinearRegression 공식, SGDRegressor(학습)
from sklearn.neural_network import MLPRegressor    # 학습(딥러닝)
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
carDF = pd.read_csv('data/cars.csv')
carDF.columns = ['speed', 'dist']
carDF
# Out:
#     speed  dist
# 0       4     2
# 1       4    10
# 2       7     4
# 3       7    22
# 4       8    16
# 5       9    10
# 6      10    18
# 7      10    26
# 8      10    34
# 9      11    17
# 10     11    28
# 11     12    14
# 12     12    20
# 13     12    24
# 14     12    28
# 15     13    26
# 16     13    34
# 17     13    34
# 18     13    46
# 19     14    26
# 20     14    36
# 21     14    60
# 22     14    80
# 23     15    20
# 24     15    26
# 25     15    54
# 26     16    32
# 27     16    40
# 28     17    32
# 29     17    40
# 30     17    50
# 31     18    42
# 32     18    56
# 33     18    76
# 34     18    84
# 35     19    36
# 36     19    46
# 37     19    68
# 38     20    32
# 39     20    48
# 40     20    52
# 41     20    56
# 42     20    64
# 43     22    66
# 44     23    54
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %%
x_data = carDF[['speed']]
y_data = carDF['dist']

# %%
# max_iter=1000 (학습횟수)
# alpha=0.0001 (learning rate)
# early_stopping=False (cost값이 변화가 없으면 학습종료)
modelSGD = SGDRegressor(max_iter=200, alpha=0.001, early_stopping=True, verbose=1)
modelSGD.fit(x_data, y_data)
# Out:
# -- Epoch 1
# Norm: 2.70, NNZs: 1, Bias: -0.620265, T: 45, Avg. loss: 666.931796
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 2.23, NNZs: 1, Bias: -0.888680, T: 90, Avg. loss: 237.540947
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 2.60, NNZs: 1, Bias: -1.138080, T: 135, Avg. loss: 185.536961
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 2.94, NNZs: 1, Bias: -1.303635, T: 180, Avg. loss: 234.931706
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 2.41, NNZs: 1, Bias: -1.497317, T: 225, Avg. loss: 279.796916
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 2.69, NNZs: 1, Bias: -1.611856, T: 270, Avg. loss: 222.891054
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 4.05, NNZs: 1, Bias: -1.676733, T: 315, Avg. loss: 232.412516
# Total training time: 0.00 seconds.
# Convergence after 7 epochs took 0.00 seconds
# SGDRegressor(alpha=0.001, early_stopping=True, max_iter=200, verbose=1)

# %%
modelSGD.coef_
# Out:
# array([4.05327519])

# %%
modelSGD.intercept_
# Out:
# array([-1.67673298])

# %%
y_predict = modelSGD.predict(x_data)
plt.scatter(x_data, y_data)
plt.plot(x_data, y_predict, 'r')
plt.show()
